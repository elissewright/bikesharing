# %%
import pandas as pd

# %%
# 1. Create a DataFrame for the 201908-citibike-tripdata data. 
tripdata_df = pd.read_csv("201908-citibike-tripdata.csv")
tripdata_df.head(10)
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           393  2019-08-01 00:00:01.4680  2019-08-01 00:06:35.3780
# 1           627  2019-08-01 00:00:01.9290  2019-08-01 00:10:29.7840
# 2          1132  2019-08-01 00:00:04.0480  2019-08-01 00:18:56.1650
# 3          1780  2019-08-01 00:00:04.1630  2019-08-01 00:29:44.7940
# 4          1517  2019-08-01 00:00:05.4580  2019-08-01 00:25:23.4550
# 5           632  2019-08-01 00:00:11.8060  2019-08-01 00:10:43.9590
# 6           117  2019-08-01 00:00:18.2010  2019-08-01 00:02:15.8600
# 7           378  2019-08-01 00:00:22.0840  2019-08-01 00:06:40.9350
# 8          1102  2019-08-01 00:00:22.0870  2019-08-01 00:18:44.3890
# 9          1733  2019-08-01 00:00:22.5580  2019-08-01 00:29:15.9080
#
#    start station id              start station name  start station latitude  \
# 0             531.0          Forsyth St & Broome St               40.718939
# 1             274.0  Lafayette Ave & Fort Greene Pl               40.686919
# 2            2000.0        Front St & Washington St               40.702551
# 3             479.0                 9 Ave & W 45 St               40.760193
# 4            3312.0                 1 Ave & E 94 St               40.781721
# 5             173.0              Broadway & W 49 St               40.760683
# 6            3718.0              E 11 St & Avenue B               40.727464
# 7             493.0                 W 45 St & 6 Ave               40.756800
# 8             355.0           Bayard St & Baxter St               40.716021
# 9             513.0                W 56 St & 10 Ave               40.768254
#
#    start station longitude  end station id            end station name  \
# 0               -73.992663           408.0       Market St & Cherry St
# 1               -73.976682          3409.0        Bergen St & Smith St
# 2               -73.989402          3388.0     President St & Henry St
# 3               -73.991255           473.0  Rivington St & Chrystie St
# 4               -73.945940          3312.0             1 Ave & E 94 St
# 5               -73.984527          3707.0     Lexington Ave & E 26 St
# 6               -73.979504           326.0             E 11 St & 1 Ave
# 7               -73.982912          3724.0  7 Ave & Central Park South
# 8               -73.999744          3232.0         Bond St & Fulton St
# 9               -73.988639           469.0          Broadway & W 53 St
#
#    end station latitude  end station longitude  bikeid    usertype  \
# 0             40.710762             -73.994004   35305  Subscriber
# 1             40.686744             -73.990632   38822  Subscriber
# 2             40.682800             -73.999904   18373  Subscriber
# 3             40.721101             -73.991925   25002  Subscriber
# 4             40.781721             -73.945940   31198  Subscriber
# 5             40.741459             -73.983293   21628  Subscriber
# 6             40.729538             -73.984267   25914  Subscriber
# 7             40.766741             -73.979069   34414  Subscriber
# 8             40.689622             -73.983043   28226  Subscriber
# 9             40.763441             -73.982681   33448    Customer
#
#    birth year  gender
# 0        1996       2
# 1        1998       2
# 2        1988       1
# 3        1988       1
# 4        1965       2
# 5        1998       1
# 6        1995       1
# 7        1999       1
# 8        1992       1
# 9        1968       1

# %%
# 2. Check the datatypes of your columns. 
tripdata_df.dtypes
# Out:
# tripduration                 int64
# starttime                   object
# stoptime                    object
# start station id           float64
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id             float64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                   int64
# gender                       int64
# dtype: object

# %%
# 3. Convert the 'tripduration' column to datetime datatype.
tripdata_df['tripduration'] = pd.to_datetime(tripdata_df['tripduration'], unit='s')
tripdata_df.sample(5)
# Out:
#                tripduration                 starttime  \
# 1128108 1970-01-01 00:02:16  2019-08-15 16:59:51.6920
# 2334949 1970-01-01 00:33:59  2019-08-31 19:35:58.2920
# 1092174 1970-01-01 00:04:45  2019-08-15 08:37:13.0820
# 1729772 1970-01-01 00:09:40  2019-08-23 18:26:24.9650
# 1952266 1970-01-01 00:17:46  2019-08-26 18:29:31.7650
#
#                          stoptime  start station id  \
# 1128108  2019-08-15 17:02:08.1660             465.0
# 2334949  2019-08-31 20:09:57.3410            3242.0
# 1092174  2019-08-15 08:41:58.1670             245.0
# 1729772  2019-08-23 18:36:05.9590            3718.0
# 1952266  2019-08-26 18:47:18.5470            3016.0
#
#                  start station name  start station latitude  \
# 1128108          Broadway & W 41 St               40.755136
# 2334949  Schermerhorn St & Court St               40.691029
# 1092174  Myrtle Ave & St Edwards St               40.693270
# 1729772          E 11 St & Avenue B               40.727464
# 1952266           Kent Ave & N 7 St               40.720368
#
#          start station longitude  end station id             end station name  \
# 1128108               -73.986580           477.0              W 41 St & 8 Ave
# 2334949               -73.991834          3571.0      Bedford Ave & Bergen St
# 1092174               -73.977039           323.0  Lawrence St & Willoughby St
# 1729772               -73.979504           312.0        Allen St & Stanton St
# 1952266               -73.961651           244.0     Willoughby Ave & Hall St
#
#          end station latitude  end station longitude  bikeid    usertype  \
# 1128108             40.756405             -73.990026   32110  Subscriber
# 2334949             40.676368             -73.952918   35154  Subscriber
# 1092174             40.692362             -73.986317   33795  Subscriber
# 1729772             40.722055             -73.989111   35031    Customer
# 1952266             40.691960             -73.965369   38774  Subscriber
#
#          birth year  gender
# 1128108        1979       1
# 2334949        1987       1
# 1092174        1989       2
# 1729772        1998       2
# 1952266        1982       1

# %%
# 4. Check the datatypes of your columns. 
tripdata_df.dtypes
# Out:
# tripduration               datetime64[ns]
# starttime                          object
# stoptime                           object
# start station id                  float64
# start station name                 object
# start station latitude            float64
# start station longitude           float64
# end station id                    float64
# end station name                   object
# end station latitude              float64
# end station longitude             float64
# bikeid                              int64
# usertype                           object
# birth year                          int64
# gender                              int64
# dtype: object

# %%
# 5. Export the Dataframe as a new CSV file without the index.
tripdata_df.to_csv("citibike-tripdata-new.csv", index=False)
